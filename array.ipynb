# %%
import array as ar 
#array is a library,that's why it is imported

# %%
ar1=ar.array('i',[1,2,3])
ar1
#i represents the integer  data type
# Out:
# array('i', [1, 2, 3])

# %%
ar1[0]#to see the element of zero index
# Out:
# 1

# %%
ar1[0]=0
ar1
#to change the zero index value
# Out:
# array('i', [0, 2, 3])

# %%
ar1[0:2]#to see the element of 0 and 1 index
# Out:
# array('i', [0, 2])

# %%
ar1.append(4)
#to add 4 as a new element

# %%
ar1
# Out:
# array('i', [0, 2, 3, 4])

# %%
del ar1[0]
#to delete the zero index value

# %%
ar1
# Out:
# array('i', [2, 3, 4])

# %%
len(ar1)
# Out:
# 3

# %%
ar1.reverse()
#to make the array in reverse order

# %%
ar1
# Out:
# array('i', [4, 3, 2])

# %%
ar1.count(4)
#to see that the element 4 how many times available in this array
# Out:
# 1

# %%
ar1.index(2)
#to check the index number of the element 2
# Out:
# 2

# %%
ar1.append(5)

# %%
ar1
# Out:
# array('i', [4, 3, 2, 5])

# %%
ar1.pop(3)
#to delete the 3rd index element
# Out:
# 5

# %%
ar1
# Out:
# array('i', [4, 3, 2])

# %%
ar1.remove(4)
#to delete specific element

# %%
ar1
# Out:
# array('i', [3, 2])

# %%
r=ar.array('i',[])
items=int(input())
for i in range(items):
    val=int(input())
    r.append(val)
print(r)
#5 items will be added newly in array called r
# Out:
#  5
#  1
#  2
#  3
#  4
#  5
# array('i', [1, 2, 3, 4, 5])

# %%
ar2=ar.array('i',[2,4,6,8,10])
ar2.extend([20, 30, 40])
print(ar2)
# add multiple elements using extend()
# Out:
# array('i', [2, 4, 6, 8, 10, 20, 30, 40])

# %%
from IPython.display import Image
Image ('array1.PNG')

# %%
from IPython.display import Image
Image ('array2.png')
